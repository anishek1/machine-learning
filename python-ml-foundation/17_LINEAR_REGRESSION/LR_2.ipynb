# %%
class MeraLin:

    def __init__(self):
        self.m=None
        self.b=None
    
    def fit(self,x_train,y_train):
        pass

    def predict(self,x_test):
        pass

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('placement.csv')
df.head(0)
# Out:
# Empty DataFrame
# Columns: [cgpa, package]
# Index: []
