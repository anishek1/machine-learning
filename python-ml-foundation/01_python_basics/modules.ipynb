# %% [markdown]
# IMPORTING MODULES

# %%
import math
math.sqrt(19)
# Out:
# 4.358898943540674

# %%
from math import *
sqrt(9
     )
# Out:
# 3.0

# %%
print(pi)
# Out:
# 3.141592653589793

# %%
print(tan)
# Out:
# <built-in function tan>
